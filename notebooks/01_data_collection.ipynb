# %%
import pandas as pd
import sys
sys.path.append('..')
from src.data_loader import load_prices

# %%
tickers=['SPY','QQQ','GLD','TLT','MSFT']
df=load_prices(tickers, '2020-01-01', '2024-12-31')
#df.head() #to check function is working
#df.isna().sum() #to check .ffill() worked on every NaN
df.describe(percentiles=[])
# Out:
# [*********************100%***********************]  5 of 5 completed
# Ticker          GLD         MSFT          QQQ          SPY          TLT
# count   1257.000000  1257.000000  1257.000000  1257.000000  1257.000000
# mean     180.834869   286.238627   337.579644   404.848522   106.829082
# std       23.898298    81.182213    78.609107    80.258570    20.339542
# min      138.039993   128.636368   163.157654   204.944870    74.540092
# max      257.500000   461.322632   533.919128   597.109375   144.320892
