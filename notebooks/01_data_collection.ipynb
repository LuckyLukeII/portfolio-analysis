# %%
import pandas as pd
import sys
sys.path.append('..')
from src.data_loader import load_prices

# %%
tickers=['SPY','QQQ','AAPL','TLT','MSFT']
df=load_prices(tickers, '2020-01-01', '2024-12-31')
#df.head() #to check function is working
#df.isna().sum() #to check .ffill() worked on every NaN
df.describe(percentiles=[])
# Out:
# [*********************100%***********************]  5 of 5 completed
# Ticker         AAPL         MSFT          QQQ          SPY          TLT
# count   1257.000000  1257.000000  1257.000000  1257.000000  1257.000000
# mean     151.439654   286.238629   337.579644   404.848524   106.436054
# std       41.816680    81.182213    78.609106    80.258576    20.264711
# min       54.213608   128.636322   163.157639   204.944839    74.265831
# max      257.612732   461.322632   533.919128   597.109436   143.789932
